# %%
import copy

import sklearn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.sparse.linalg import eigsh
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

import explore_heuristic
import experiment_utils

# %%
data = pd.read_csv('loc-brightkite_totalCheckins.txt', sep='\t', names=['zero', 'time', 'latitude', 'longitude', 'location id'])

# %%
def ground_truth_kmeans(full_data):
    # Initialize and fit the K-Means model
    temp_kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    temp_kmeans.fit(full_data)

    return temp_kmeans

# %%
def random_subsample(full_data, num_samples):
    """Return a random subset of N samples from all the data."""
    perm = np.random.permutation(full_data.shape[0])
    less_data = copy.deepcopy(full_data[perm][:num_samples])
    return less_data

# %%
# Filter for relevant columns and drop any rows with missing latitude or longitude
location_data = data[['latitude', 'longitude']].dropna()

# Number of clusters - adjust based on your goal
num_clusters = 10

# Constant for subsample size
subsample_size = 500

location_data_array = location_data[['latitude', 'longitude']].to_numpy()

all_locations_k_means = ground_truth_kmeans(location_data_array)

subsample_data_array = random_subsample(location_data_array, subsample_size)
subsample_k_means = ground_truth_kmeans(
    subsample_data_array
)
# Out:
# /Users/beneyre/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/beneyre/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
# Experiment with model performance by keeping the number
# of sampling rounds fixed, but increasing the sample number.
from importlib import reload
reload(explore_heuristic)
reload(experiment_utils)

fixed_number_of_rounds = 15
oracle_acc_lists = []
random_acc_lists = []
distance_acc_lists = []


samp_settings = [1, 2, 4, 5, 7, 10, 25, 50, 100, 250]

samp_xticks = ["{}".format(samps) for samps in samp_settings]

for samp_num in samp_settings:
    print("On samp num {}".format(samp_num))
    oracle_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, fixed_number_of_rounds,
        samp_num, method="random", retraining="query")
    )
    random_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, fixed_number_of_rounds,
        samp_num, method="random", retraining="online")
    )
    distance_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, fixed_number_of_rounds,
        samp_num, method="distance", retraining="online")
    )

experiment_utils.acc_plot(
    [oracle_acc_lists, random_acc_lists, distance_acc_lists],
    ["oracle", "random", "distance"], xticks=samp_xticks
)
# Out:
# On samp num 1
# Mean accuracy 0.53604
# Std accuracy 0.14611173258845436
# Mean accuracy 0.55208
# Std accuracy 0.15898576540055404
# Mean accuracy 0.5770199999999999
# Std accuracy 0.13678757107281347
# On samp num 2
# Mean accuracy 0.69034
# Std accuracy 0.15109495160328817
# Mean accuracy 0.69544
# Std accuracy 0.13105726382005692
# Mean accuracy 0.74592
# Std accuracy 0.10226511428634888
# On samp num 4
# Mean accuracy 0.8385599999999998
# Std accuracy 0.08304990307038293
# Mean accuracy 0.8153599999999999
# Std accuracy 0.11204244909854479
# Mean accuracy 0.8579400000000001
# Std accuracy 0.0798044885955671
# On samp num 5
# Mean accuracy 0.85828
# Std accuracy 0.09102088551535849
# Mean accuracy 0.8428999999999999
# Std accuracy 0.09942208004261427
# Mean accuracy 0.8970199999999999
# Std accuracy 0.05727023310586399
# On samp num 7
# Mean accuracy 0.9158399999999999
# Std accuracy 0.06119717640545191
# Mean accuracy 0.8827999999999999
# Std accuracy 0.08658406319872035
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Mean accuracy 0.94158
# Std accuracy 0.04248792298995092
# On samp num 10
# Mean accuracy 0.9234799999999999
# Std accuracy 0.061778067305476615
# Mean accuracy 0.9316
# Std accuracy 0.055663991951709686
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Mean accuracy 0.9435400000000002
# Std accuracy 0.04473285593386588
# On samp num 25
# Mean accuracy 0.9786
# Std accuracy 0.030365111559156183
# Mean accuracy 0.9630200000000002
# Std accuracy 0.04167348797497037
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 21 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 21 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 21 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Mean accuracy 0.93792
# Std accuracy 0.045300701981315916
# On samp num 50
# Mean accuracy 0.9866799999999999
# Std accuracy 0.02300994567572901
# Mean accuracy 0.9716600000000001
# Std accuracy 0.023851297658618067
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 39 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 48 samples
# Exceeded max iterations!
# Space filled, only retrieved 28 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 45 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 30 samples
# Exceeded max iterations!
# Space filled, only retrieved 34 samples
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 39 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 47 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Exceeded max iterations!
# Space filled, only retrieved 28 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 28 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 28 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 45 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 28 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 25 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 34 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 35 samples
# Exceeded max iterations!
# Space filled, only retrieved 43 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 47 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 35 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 25 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 35 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Mean accuracy 0.93678
# Std accuracy 0.04573829467743631
# On samp num 100
# Mean accuracy 0.9927800000000002
# Std accuracy 0.015663703265830855
# Mean accuracy 0.98098
# Std accuracy 0.013343148054338609
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 47 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 52 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 55 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 34 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 44 samples
# Exceeded max iterations!
# Space filled, only retrieved 61 samples
# Exceeded max iterations!
# Space filled, only retrieved 44 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 43 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 90 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 30 samples
# Exceeded max iterations!
# Space filled, only retrieved 35 samples
# Exceeded max iterations!
# Space filled, only retrieved 21 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 28 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 28 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 58 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 44 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 63 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 43 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 25 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 52 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Exceeded max iterations!
# Space filled, only retrieved 44 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 21 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 54 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 39 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 45 samples
# Exceeded max iterations!
# Space filled, only retrieved 68 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 39 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 34 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 65 samples
# Exceeded max iterations!
# Space filled, only retrieved 44 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Mean accuracy 0.9495199999999998
# Std accuracy 0.03396247340816035
# On samp num 250
# Mean accuracy 0.99386
# Std accuracy 0.015044613654062388
# Mean accuracy 0.9409199999999999
# Std accuracy 0.02166364696905853
# Exceeded max iterations!
# Space filled, only retrieved 108 samples
# Exceeded max iterations!
# Space filled, only retrieved 194 samples
# Exceeded max iterations!
# Space filled, only retrieved 183 samples
# Exceeded max iterations!
# Space filled, only retrieved 114 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 139 samples
# Exceeded max iterations!
# Space filled, only retrieved 241 samples
# Exceeded max iterations!
# Space filled, only retrieved 98 samples
# Exceeded max iterations!
# Space filled, only retrieved 131 samples
# Exceeded max iterations!
# Space filled, only retrieved 148 samples
# Exceeded max iterations!
# Space filled, only retrieved 97 samples
# Exceeded max iterations!
# Space filled, only retrieved 187 samples
# Exceeded max iterations!
# Space filled, only retrieved 214 samples
# Exceeded max iterations!
# Space filled, only retrieved 172 samples
# Exceeded max iterations!
# Space filled, only retrieved 149 samples
# Exceeded max iterations!
# Space filled, only retrieved 116 samples
# Exceeded max iterations!
# Space filled, only retrieved 69 samples
# Exceeded max iterations!
# Space filled, only retrieved 165 samples
# Exceeded max iterations!
# Space filled, only retrieved 163 samples
# Exceeded max iterations!
# Space filled, only retrieved 68 samples
# Exceeded max iterations!
# Space filled, only retrieved 159 samples
# Exceeded max iterations!
# Space filled, only retrieved 71 samples
# Exceeded max iterations!
# Space filled, only retrieved 158 samples
# Exceeded max iterations!
# Space filled, only retrieved 140 samples
# Exceeded max iterations!
# Space filled, only retrieved 117 samples
# Exceeded max iterations!
# Space filled, only retrieved 121 samples
# Exceeded max iterations!
# Space filled, only retrieved 157 samples
# Exceeded max iterations!
# Space filled, only retrieved 155 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 120 samples
# Exceeded max iterations!
# Space filled, only retrieved 164 samples
# Exceeded max iterations!
# Space filled, only retrieved 170 samples
# Exceeded max iterations!
# Space filled, only retrieved 171 samples
# Exceeded max iterations!
# Space filled, only retrieved 156 samples
# Exceeded max iterations!
# Space filled, only retrieved 93 samples
# Exceeded max iterations!
# Space filled, only retrieved 153 samples
# Exceeded max iterations!
# Space filled, only retrieved 129 samples
# Exceeded max iterations!
# Space filled, only retrieved 108 samples
# Exceeded max iterations!
# Space filled, only retrieved 179 samples
# Exceeded max iterations!
# Space filled, only retrieved 87 samples
# Exceeded max iterations!
# Space filled, only retrieved 135 samples
# Exceeded max iterations!
# Space filled, only retrieved 131 samples
# Exceeded max iterations!
# Space filled, only retrieved 134 samples
# Exceeded max iterations!
# Space filled, only retrieved 183 samples
# Exceeded max iterations!
# Space filled, only retrieved 105 samples
# Exceeded max iterations!
# Space filled, only retrieved 170 samples
# Exceeded max iterations!
# Space filled, only retrieved 109 samples
# Exceeded max iterations!
# Space filled, only retrieved 123 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 137 samples
# Exceeded max iterations!
# Space filled, only retrieved 126 samples
# Exceeded max iterations!
# Space filled, only retrieved 137 samples
# Exceeded max iterations!
# Space filled, only retrieved 201 samples
# Exceeded max iterations!
# Space filled, only retrieved 189 samples
# Exceeded max iterations!
# Space filled, only retrieved 87 samples
# Exceeded max iterations!
# Space filled, only retrieved 83 samples
# Exceeded max iterations!
# Space filled, only retrieved 125 samples
# Exceeded max iterations!
# Space filled, only retrieved 139 samples
# Exceeded max iterations!
# Space filled, only retrieved 92 samples
# Exceeded max iterations!
# Space filled, only retrieved 172 samples
# Exceeded max iterations!
# Space filled, only retrieved 177 samples
# Exceeded max iterations!
# Space filled, only retrieved 141 samples
# Exceeded max iterations!
# Space filled, only retrieved 107 samples
# Exceeded max iterations!
# Space filled, only retrieved 133 samples
# Exceeded max iterations!
# Space filled, only retrieved 118 samples
# Exceeded max iterations!
# Space filled, only retrieved 164 samples
# Exceeded max iterations!
# Space filled, only retrieved 189 samples
# Exceeded max iterations!
# Space filled, only retrieved 128 samples
# Exceeded max iterations!
# Space filled, only retrieved 103 samples
# Exceeded max iterations!
# Space filled, only retrieved 195 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 199 samples
# Exceeded max iterations!
# Space filled, only retrieved 93 samples
# Exceeded max iterations!
# Space filled, only retrieved 148 samples
# Exceeded max iterations!
# Space filled, only retrieved 136 samples
# Exceeded max iterations!
# Space filled, only retrieved 146 samples
# Exceeded max iterations!
# Space filled, only retrieved 161 samples
# Exceeded max iterations!
# Space filled, only retrieved 133 samples
# Exceeded max iterations!
# Space filled, only retrieved 131 samples
# Exceeded max iterations!
# Space filled, only retrieved 181 samples
# Exceeded max iterations!
# Space filled, only retrieved 135 samples
# Exceeded max iterations!
# Space filled, only retrieved 170 samples
# Exceeded max iterations!
# Space filled, only retrieved 113 samples
# Exceeded max iterations!
# Space filled, only retrieved 90 samples
# Exceeded max iterations!
# Space filled, only retrieved 63 samples
# Exceeded max iterations!
# Space filled, only retrieved 158 samples
# Exceeded max iterations!
# Space filled, only retrieved 175 samples
# Exceeded max iterations!
# Space filled, only retrieved 133 samples
# Exceeded max iterations!
# Space filled, only retrieved 201 samples
# Exceeded max iterations!
# Space filled, only retrieved 192 samples
# Exceeded max iterations!
# Space filled, only retrieved 97 samples
# Exceeded max iterations!
# Space filled, only retrieved 125 samples
# Exceeded max iterations!
# Space filled, only retrieved 163 samples
# Exceeded max iterations!
# Space filled, only retrieved 191 samples
# Exceeded max iterations!
# Space filled, only retrieved 127 samples
# Exceeded max iterations!
# Space filled, only retrieved 109 samples
# Exceeded max iterations!
# Space filled, only retrieved 105 samples
# Exceeded max iterations!
# Space filled, only retrieved 75 samples
# Exceeded max iterations!
# Space filled, only retrieved 108 samples
# Exceeded max iterations!
# Space filled, only retrieved 128 samples
# Mean accuracy 0.9304800000000002
# Std accuracy 0.053087188661672405

# %%
# Experiment with model performance by keeping the number
# of sampling rounds fixed, but increasing the sample number.
from importlib import reload
reload(explore_heuristic)
reload(experiment_utils)

fixed_number_of_samps = 15
rounds_oracle_acc_lists = []
rounds_random_acc_lists = []
rounds_distance_acc_lists = []

round_settings = [1, 2, 4, 5, 7, 10, 25, 50, 100, 250]

round_xticks = ["{}".format(rounds) for rounds in round_settings]

for round_num in round_settings:
    print("On round num {}".format(round_num))
    rounds_oracle_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, round_num,
        fixed_number_of_samps, method="random", retraining="query")
    )
    rounds_random_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, round_num,
        fixed_number_of_samps, method="random", retraining="online")
    )
    rounds_distance_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, round_num,
        fixed_number_of_samps, method="distance", retraining="online")
    )
experiment_utils.acc_plot(
    [rounds_oracle_acc_lists, rounds_random_acc_lists, rounds_distance_acc_lists],
    ["oracle", "random", "distance"], xticks=round_xticks
)
# Out:
# On round num 1
# Mean accuracy 0.5552999999999999
# Std accuracy 0.1507364255911623
# Mean accuracy 0.57664
# Std accuracy 0.12114549269370281
# Mean accuracy 0.57034
# Std accuracy 0.13338457332090545
# On round num 2
# Mean accuracy 0.7089799999999999
# Std accuracy 0.1228027670698018
# Mean accuracy 0.7022199999999998
# Std accuracy 0.10786914109234391
# Mean accuracy 0.7407400000000002
# Std accuracy 0.1114639511232219
# On round num 4
# Mean accuracy 0.8224199999999997
# Std accuracy 0.10211299427594903
# Mean accuracy 0.80036
# Std accuracy 0.091776415271027
# Mean accuracy 0.8666200000000002
# Std accuracy 0.08945063219452391
# On round num 5
# Mean accuracy 0.8595599999999999
# Std accuracy 0.09378425454200721
# Mean accuracy 0.8494800000000001
# Std accuracy 0.08344752602683916
# Mean accuracy 0.8957599999999999
# Std accuracy 0.0720556895741065
# On round num 7
# Mean accuracy 0.8865000000000002
# Std accuracy 0.09050939177787021
# Mean accuracy 0.87878
# Std accuracy 0.0815862218760006
# Mean accuracy 0.92798
# Std accuracy 0.05766072840330756
# On round num 10
# Mean accuracy 0.9357800000000001
# Std accuracy 0.05676258979292612
# Mean accuracy 0.91196
# Std accuracy 0.07547660829687565
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Mean accuracy 0.9515
# Std accuracy 0.03845971918774238
# On round num 25
# Mean accuracy 0.9748799999999999
# Std accuracy 0.029146965536741554
# Mean accuracy 0.9713200000000001
# Std accuracy 0.03054337243986001
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Mean accuracy 0.9402999999999999
# Std accuracy 0.04685072037866653
# On round num 50
# Mean accuracy 0.9819999999999999
# Std accuracy 0.03025623902602569
# Mean accuracy 0.9835
# Std accuracy 0.018696256309753564
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Mean accuracy 0.9471400000000003
# Std accuracy 0.04196213054648202
# On round num 100
# Mean accuracy 0.9953799999999999
# Std accuracy 0.01191199395567342
# Mean accuracy 0.98996
# Std accuracy 0.011811790719446403
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Mean accuracy 0.9433
# Std accuracy 0.04552043497155975
# On round num 250
# Mean accuracy 0.9968400000000002
# Std accuracy 0.007880000000000009
# Mean accuracy 0.9919600000000002
# Std accuracy 0.015597384396109495
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Mean accuracy 0.9405799999999997
# Std accuracy 0.04557832379541836

# %%
# Experiment with model performance by keeping the total number
# of samples fixed, but testing out different variations on how
# to procure that amount.
from importlib import reload
reload(explore_heuristic)
reload(experiment_utils)

perm_oracle_acc_lists = []
perm_random_acc_lists = []
perm_distance_acc_lists = []

# We'll always sample 200 samples.

sample_settings = [(1, 200), (2, 100), (4, 50), (5, 40), (10, 20), (50, 4), (100, 2), (200, 1)]

sample_xticks = ["{}_{}".format(rounds, samps) for (rounds, samps) in sample_settings]

for (rounds, samps) in sample_settings:
    print("Rounds {}, samps {}".format(rounds, samps))
    perm_oracle_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, rounds,
        samps, method="random", retraining="query")
    )
    perm_random_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, rounds,
        samps, method="random", retraining="online")
    )
    perm_distance_acc_lists.append(
        experiment_utils.attack_experiment(subsample_data_array, subsample_k_means, rounds,
        samps, method="distance", retraining="online")
    )
experiment_utils.acc_plot(
    [perm_oracle_acc_lists, perm_random_acc_lists, perm_distance_acc_lists],
    ["oracle", "random", "distance"], xticks=sample_xticks
)
# Out:
# Rounds 1, samps 200
# Mean accuracy 0.95002
# Std accuracy 0.045463387467279646
# Mean accuracy 0.91912
# Std accuracy 0.04689846052910479
# Mean accuracy 0.93598
# Std accuracy 0.043236553979243066
# Rounds 2, samps 100
# Mean accuracy 0.9485799999999999
# Std accuracy 0.05347245646124741
# Mean accuracy 0.92758
# Std accuracy 0.05553110479722152
# Mean accuracy 0.9410599999999999
# Std accuracy 0.043378755168861166
# Rounds 4, samps 50
# Mean accuracy 0.95248
# Std accuracy 0.04524344814445512
# Mean accuracy 0.92732
# Std accuracy 0.0536993258803125
# Exceeded max iterations!
# Space filled, only retrieved 30 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 35 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 30 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 39 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 43 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 21 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 37 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 47 samples
# Exceeded max iterations!
# Space filled, only retrieved 45 samples
# Exceeded max iterations!
# Space filled, only retrieved 43 samples
# Exceeded max iterations!
# Space filled, only retrieved 32 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 46 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 36 samples
# Exceeded max iterations!
# Space filled, only retrieved 47 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 39 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 43 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 46 samples
# Exceeded max iterations!
# Space filled, only retrieved 20 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 44 samples
# Exceeded max iterations!
# Space filled, only retrieved 47 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 34 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 33 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 41 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 38 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 30 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 40 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 34 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 31 samples
# Exceeded max iterations!
# Space filled, only retrieved 34 samples
# Exceeded max iterations!
# Space filled, only retrieved 42 samples
# Exceeded max iterations!
# Space filled, only retrieved 45 samples
# Exceeded max iterations!
# Space filled, only retrieved 26 samples
# Exceeded max iterations!
# Space filled, only retrieved 43 samples
# Mean accuracy 0.9518599999999999
# Std accuracy 0.03777751182912923
# Rounds 5, samps 40
# Mean accuracy 0.9507599999999999
# Std accuracy 0.046074530925447305
# Mean accuracy 0.9410999999999998
# Std accuracy 0.0500850277028974
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 24 samples
# Exceeded max iterations!
# Space filled, only retrieved 27 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 22 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 21 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 23 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 29 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Mean accuracy 0.94222
# Std accuracy 0.04732601398808058
# Rounds 10, samps 20
# Mean accuracy 0.9509799999999998
# Std accuracy 0.0462285582729983
# Mean accuracy 0.9460399999999999
# Std accuracy 0.04305808170367091
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 6 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 4 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 17 samples
# Exceeded max iterations!
# Space filled, only retrieved 15 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 9 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 12 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 10 samples
# Exceeded max iterations!
# Space filled, only retrieved 18 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Space filled, only retrieved 16 samples
# Exceeded max iterations!
# Space filled, only retrieved 7 samples
# Exceeded max iterations!
# Space filled, only retrieved 19 samples
# Exceeded max iterations!
# Space filled, only retrieved 8 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 5 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 13 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 14 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 11 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Mean accuracy 0.94902
# Std accuracy 0.04187170404939355
# Rounds 50, samps 4
# Mean accuracy 0.9525
# Std accuracy 0.04423878388925265
# Mean accuracy 0.9420999999999999
# Std accuracy 0.05133215366609899
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 2 samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Exceeded max iterations!
# Space filled, only retrieved 3 samples
# Mean accuracy 0.93798
# Std accuracy 0.04999559580603075
# Rounds 100, samps 2
# Mean accuracy 0.9583399999999999
# Std accuracy 0.04044557330536927
# Mean accuracy 0.9467200000000001
# Std accuracy 0.04940730310389345
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, only retrieved 1 samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Mean accuracy 0.9371
# Std accuracy 0.04739989451465055
# Rounds 200, samps 1
# Mean accuracy 0.9470800000000001
# Std accuracy 0.043459792912530076
# Mean accuracy 0.95076
# Std accuracy 0.04323126646305889
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Exceeded max iterations!
# Space filled, did not retrieve samples
# Mean accuracy 0.9431599999999999
# Std accuracy 0.05070635463134773
